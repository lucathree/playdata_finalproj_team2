# %%
import os
from glob import glob
import random
import numpy as np
import pandas as pd

from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', -1)

#pd.options.display.max_columns = 20
#pd.options.display.max_rows = 10

# %%
cur_dir = '/home/ubuntu/aiml/data/'
cur_dir
# Out:
# '/home/ubuntu/aiml/data/'

# %%
# !ls .
# Out:
# Amazon_SageMaker_Tutorial.ipynb   lane_detection  traffic_lane_dataset.ipynb
# fashionMNIST_preprocessing.ipynb  pytorch_lesson  Untitled.ipynb

# %%
os.listdir(cur_dir)
# Out:
# ['FashionMNIST',
#  'traffic_lane',
#  '.ipynb_checkpoints',
#  'MNIST',
#  'The_Oxford-IIIT_Pet_Dataset']

# %%
data_dir = os.path.join(cur_dir, 'traffic_lane')
data_dir
# Out:
# '/home/ubuntu/aiml/data/traffic_lane'

# %%
os.listdir(data_dir)
# Out:
# ['Training', '.ipynb_checkpoints', 'Validation']

# %%
train_dir = os.path.join(data_dir, 'Training')
val_dir = os.path.join(data_dir, 'Validation')

# %%
print(train_dir)
print(val_dir)
# Out:
# /home/ubuntu/aiml/data/traffic_lane/Training
# /home/ubuntu/aiml/data/traffic_lane/Validation

# %%
os.listdir(train_dir)
# Out:
# ['[img]c_1280_720_daylight_train_1.tar',
#  '[img]c_1280_720_daylight_train_2.tar',
#  '[img]c_1280_720_daylight_train_3.tar',
#  '[img]c_1280_720_daylight_train_7.tar',
#  '[img]c_1280_720_daylight_train_4.tar',
#  '[img]c_1280_720_daylight_train_5.tar',
#  '[img]c_1280_720_daylight_train_8.tar',
#  '[img]c_1280_720_night_train_1.tar',
#  '[img]c_1280_720_night_train_2.tar',
#  '[img]c_1280_720_night_train_3.tar',
#  '[img]c_1280_720_night_train_4.tar',
#  '[img]c_1280_720_daylight_train_6.tar',
#  '[label]c_1280_720_daylight_train_3.zip',
#  '[label]c_1280_720_daylight_train_2.zip',
#  '[label]c_1280_720_daylight_train_1.zip',
#  '[label]c_1280_720_daylight_train_4.zip',
#  '[label]c_1280_720_daylight_train_5.zip',
#  '[label]c_1280_720_daylight_train_7.zip',
#  '[label]c_1280_720_daylight_train_6.zip',
#  '[label]c_1280_720_night_train_4.tar',
#  '[label]c_1280_720_night_train_1.tar',
#  '[label]c_1280_720_night_train_2.tar',
#  '[label]c_1280_720_night_train_3.tar',
# ...

# %%
os.listdir(val_dir)
# Out:
# ['[img]c_1280_720_daylight_validation_1.tar',
#  '[img]c_1280_720_night_validation_1.tar',
#  '[label]c_1280_720_daylight_validation_1.tar',
#  '[label]c_1280_720_night_validation_1.tar',
#  'c_1280_720_daylight_val_1',
#  'c_1280_720_night_validation_1']

# %%
[x for x in os.walk(train_dir)]
# Out:
# [('/home/ubuntu/aiml/data/traffic_lane/Training',
#   ['c_1280_720_daylight_train_1',
#    'c_1280_720_daylight_train_2',
#    'c_1280_720_daylight_train_3',
#    'c_1280_720_daylight_train_4',
#    'c_1280_720_daylight_train_5',
#    'c_1280_720_daylight_train_6',
#    'c_1280_720_daylight_train_7',
#    'c_1280_720_daylight_train_8',
#    'c_1280_720_night_train_1',
#    'c_1280_720_night_train_2',
#    'c_1280_720_night_train_3',
#    'c_1280_720_night_train_4'],
#   ['[img]c_1280_720_daylight_train_1.tar',
#    '[img]c_1280_720_daylight_train_2.tar',
#    '[img]c_1280_720_daylight_train_3.tar',
#    '[img]c_1280_720_daylight_train_7.tar',
#    '[img]c_1280_720_daylight_train_4.tar',
#    '[img]c_1280_720_daylight_train_5.tar',
#    '[img]c_1280_720_daylight_train_8.tar',
#    '[img]c_1280_720_night_train_1.tar',
#    '[img]c_1280_720_night_train_2.tar',
#    '[img]c_1280_720_night_train_3.tar',
#    '[img]c_1280_720_night_train_4.tar',
# ...

# %%
[x[0] for x in os.walk(train_dir)]
# Out:
# ['/home/ubuntu/aiml/data/traffic_lane/Training',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/json',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_2',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_2/json',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_2/image',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_3',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_3/json',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_3/image',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_4',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_4/json',
# ...

# %%
glob(train_dir+"/*/")
# Out:
# ['/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_2/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_3/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_4/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_5/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_6/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_7/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_8/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_1/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_2/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_3/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_4/']

# %%
glob(train_dir+"/**/*/")
# Out:
# ['/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/json/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_2/json/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_2/image/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_3/json/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_3/image/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_4/json/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_4/image/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_5/json/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_5/image/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_6/json/',
# ...

# %%
glob(train_dir+"/**/image/")
# Out:
# ['/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_2/image/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_3/image/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_4/image/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_5/image/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_6/image/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_7/image/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_8/image/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_1/image/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_2/image/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_3/image/',
# ...

# %%
for p in glob(train_dir+"/**/image/"):
    print(p)
# Out:
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image/
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_2/image/
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_3/image/
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_4/image/
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_5/image/
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_6/image/
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_7/image/
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_8/image/
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_1/image/
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_2/image/
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_3/image/
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_4/image/

# %%
glob(train_dir+"/**/json/")
# Out:
# ['/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/json/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_2/json/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_3/json/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_4/json/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_5/json/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_6/json/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_7/json/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_8/json/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_1/json/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_2/json/',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_3/json/',
# ...

# %%
for p in glob(val_dir+"/**/image/"):
    print(p)
# Out:
# /home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_daylight_val_1/image/
# /home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_night_validation_1/image/

# %%
glob(train_dir+"/**/image/*.jpg")
# Out:
# ['/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image/16608323.jpg',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image/16608423.jpg',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image/16608466.jpg',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image/16608467.jpg',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image/16608468.jpg',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image/16608469.jpg',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image/16608470.jpg',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image/16608471.jpg',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image/16608472.jpg',
#  '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image/16608473.jpg',
# ...

# %%
df = pd.DataFrame(glob(train_dir+"/**/image/*.jpg"), columns = ['image'])

# %%
df.head()
# Out:
#                                                                                          image
# 0  /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image/16608323.jpg
# 1  /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image/16608423.jpg
# 2  /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image/16608466.jpg
# 3  /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image/16608467.jpg
# 4  /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image/16608468.jpg

# %%
df['label'] = df.apply(lambda x: x['image'].split('.')[0]+'.json', axis=1)

# %%
"/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image/16608323.json".replace("/image/", "/json/")
# Out:
# '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/json/16608323.json'

# %%
df['label'] = df['label'].apply(lambda x: x.replace("/image/", "/json/"))

# %%
df.tail()
# Out:
#                                                                                           image  \
# 334024  /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_4/image/9990932.jpg
# 334025  /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_4/image/9990933.jpg
# 334026  /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_4/image/9990934.jpg
# 334027  /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_4/image/9990935.jpg
# 334028  /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_4/image/9990936.jpg
#
#                                                                                           label
# 334024  /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_4/json/9990932.json
# 334025  /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_4/json/9990933.json
# 334026  /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_4/json/9990934.json
# ...

# %%
df.shape
# Out:
# (334029, 2)

# %%
df_test = pd.DataFrame(glob(val_dir+"/**/image/*.jpg"), columns = ['image'])
df_test['label'] = df_test.apply(lambda x: x['image'].split('.')[0]+'.json', axis=1)

# %%
df_test['label'] = df_test['label'].apply(lambda x: x.replace("/image/", "/json/"))
df_test.tail()
# Out:
#                                                                                                 image  \
# 41895  /home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_night_validation_1/image/9996780.jpg
# 41896  /home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_night_validation_1/image/9996781.jpg
# 41897  /home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_night_validation_1/image/9996782.jpg
# 41898  /home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_night_validation_1/image/9996783.jpg
# 41899  /home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_night_validation_1/image/9996784.jpg
#
#                                                                                                 label
# 41895  /home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_night_validation_1/json/9996780.json
# 41896  /home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_night_validation_1/json/9996781.json
# ...

# %%
df_test.shape
# Out:
# (41900, 2)

# %%
for d_image in glob(train_dir+"/**/image/"):
    print(d_image, len(glob(d_image + "/*.jpg")))
    d_json = d_image.replace('/image/', '/json/')
    print(d_json, len(glob(d_json + "/*.json")))
# Out:
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image/ 30000
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/json/ 30000
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_2/image/ 30000
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_2/json/ 30000
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_3/image/ 30000
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_3/json/ 30000
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_4/image/ 30000
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_4/json/ 30000
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_5/image/ 30000
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_5/json/ 30000
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_6/image/ 30000
# ...

# %%
for d_image in glob(val_dir+"/**/image/"):
    print(d_image, len(glob(d_image + "/*.jpg")))
    d_json = d_image.replace('/image/', '/json/')
    print(d_json, len(glob(d_json + "/*.json")))
# Out:
# /home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_daylight_val_1/image/ 27700
# /home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_daylight_val_1/json/ 27700
# /home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_night_validation_1/image/ 14200
# /home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_night_validation_1/json/ 14200

# %%
random.seed(1234)

# %%
random.randint(0, 3)
# Out:
# 3

# %%
rnd_idx = random.randint(0, len(df)-1)
rnd_idx
# Out:
# 61263

# %%
img_path = df.iloc[rnd_idx, 0]
img = Image.open(img_path)
img_arr = np.array(img)

plt.figure(figsize=(12,9))
plt.imshow(img_arr)
plt.show()

# %%
rnd_idx_list = random.sample(range(0, len(df)), 6)
rnd_idx_list
# Out:
# [3927, 47523, 305254, 18311, 44007, 51601]

# %%
plt.figure(figsize=(18, 9))
for i, idx in enumerate(rnd_idx_list):
    plt.subplot(2, 3, i+1)
    plt.imshow(np.array(Image.open(df.iloc[idx, 0])))
plt.show()

# %%
## module.py

from datasets import LaneDataset

class NIA_SEGNet_module(pl.LightningModule):

    def val_dataloader(self):
        dataset = LaneDataset(data_path='data/val_iyl.txt')
        train_loader = DataLoader(dataset, batch_size = self.batch_size, num_workers=28)
        return train_loader

    def test_dataloader(self):
        dataset = LaneDataset(data_path='data/sample.txt')
        train_loader = DataLoader(dataset, batch_size = self.batch_size, num_workers=12)
        return train_loader

    def train_dataloader(self):
        dataset = LaneDataset(data_path='data/train_iyl.txt')
        train_loader = DataLoader(dataset, batch_size = self.batch_size, num_workers=12,shuffle=True)
        return train_loader
# Out:
# "\nfrom datasets import LaneDataset\n\nclass NIA_SEGNet_module(pl.LightningModule):\n\n    def val_dataloader(self):\n        dataset = LaneDataset(data_path='data/val_iyl.txt')\n        train_loader = DataLoader(dataset, batch_size = self.batch_size, num_workers=28)\n        return train_loader\n\n    def test_dataloader(self):\n        dataset = LaneDataset(data_path='data/sample.txt')\n        train_loader = DataLoader(dataset, batch_size = self.batch_size, num_workers=12)\n        return train_loader\n\n    def train_dataloader(self):\n        dataset = LaneDataset(data_path='data/train_iyl.txt')\n        train_loader = DataLoader(dataset, batch_size = self.batch_size, num_workers=12,shuffle=True)\n        return train_loader\n"

# %%
from datasets import LaneDataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-40-2eb1eda62772> in <module>()
# ----> 1 from datasets import LaneDataset
#
# ModuleNotFoundError: No module named 'datasets'

# %%
#data_path = "/train_tmp.txt"
data_path = "/home/ubuntu/aiml/lane_model/lane_detection/data/test_iyl.txt"

# %%
with open(data_path) as txt:
    lines = txt.readlines()

lines
# Out:
# ['/home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_daylight_val_1/image/\n',
#  '/home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_night_validation_1/image/\n']

# %%
img_list = []
for line in lines:
    img_list += [line.strip()+'/'+f for f in os.listdir(line.strip()) if ".jpg" in f or '.png' in f]

img_list
# Out:
# ['/home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_daylight_val_1/image//10002688.jpg',
#  '/home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_daylight_val_1/image//10002689.jpg',
#  '/home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_daylight_val_1/image//10002690.jpg',
#  '/home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_daylight_val_1/image//10002691.jpg',
#  '/home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_daylight_val_1/image//10002692.jpg',
#  '/home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_daylight_val_1/image//10002693.jpg',
#  '/home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_daylight_val_1/image//10002694.jpg',
#  '/home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_daylight_val_1/image//10002695.jpg',
#  '/home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_daylight_val_1/image//10002696.jpg',
#  '/home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_daylight_val_1/image//10002697.jpg',
# ...

# %%
len_ = len(img_list)
#self.data_path = data_path

print(len_)
# Out:
# 41900

# %%
img_list[4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b502bf437cc4> in <module>()
# ----> 1 img_list[4]
#
# NameError: name 'img_list' is not defined

# %%
import ujson as json

# %%
# json check
for i, path in enumerate(img_list):
    print(i, path)
    label_path = path.replace("image","json").replace('.jpg','.json').replace('.png','.json')
    with open(label_path) as json_file:
        json_data = json.load(json_file)
    annotation = json_data["annotations"]
    
    for item in annotation:  #001
        obj_class = item["class"]
        if obj_class == "traffic_lane":
            pos = item["data"]
            poly_points = np.array([([pt["x"], pt["y"]]) for pt in pos]).astype(np.int32)
        if obj_class == "stop_line":
            pos = item["data"]
            poly_points = np.array([([pt["x"], pt["y"]]) for pt in pos]).astype(np.int32)
        if obj_class == "crosswalk":
            pos = item["data"]
            poly_points = np.array([([pt["x"], pt["y"]]) for pt in pos]).astype(np.int32)

# %% [markdown]
# error
# '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_3/json/15320585.json' : 수정

# %%
obj_class

# %%
label_path = img_list[273457].replace("image","json").replace('.jpg','.json').replace('.png','.json')
label_path

# %%
with open(label_path) as json_file:
    json_data = json.load(json_file)

# %%
json_data

# %%
ld = LaneDataset(data_path)
ld

# %%
ld.data_path

# %%
ld.img_list

# %%
ld.len

# %%
ld.make_gt_map

# %%
from PIL import Image

# %%
#def __getitem__(self, index):
index = 0

while True:
    img_path = ld.img_list[index]
    try:
        img = Image.open(img_path)
        break
    except:
        with open("error_files.txt",'a') as errlog:
            errlog.write(img_path+'\n')
            index = index + 1

img_path

# %%
w, h = img.size
label_path = img_path.replace("image","json").replace('.jpg','.json').replace('.png','.json')

print(w, h, label_path)

# %%
import ujson as json
from torchvision import transforms
import cv2

# %%
with open(label_path) as json_file:
    json_data = json.load(json_file)
img_tensor = transforms.functional.to_tensor(transforms.functional.resized_crop(img, h-w//2, 0, w//2, w, (ld.I_H,ld.I_W)))

img_tensor

# %%
json_data

# %%
target_map = ld.make_gt_map(json_data, w, h)

target_map

# %%
#    def make_gt_map(self, json_data, original_w, original_h):
original_w = w 
original_h = h

target_map = np.zeros((ld.I_H, ld.I_W),dtype=np.int32)

target_map

# %%
print(ld.I_H, ld.I_W)

# %%
target_map.shape

# %%
annotation = json_data["annotations"]

annotation

# %%
y_offset = original_h - original_w // 2
for item in annotation:  #001
    obj_class = item["class"]
    if obj_class == "traffic_lane":
        pos = item["data"]
        poly_points = np.array([([pt["x"]*ld.I_W/original_w, (pt["y"] - y_offset)*ld.I_H/(original_h-y_offset)]) for pt in pos]).astype(np.int32)
        cv2.polylines(target_map, [poly_points], False, 1,10)
    if obj_class == "stop_line":
        pos = item["data"]
        poly_points = np.array([([pt["x"]*ld.I_W/original_w, (pt["y"] - y_offset)*ld.I_H/(original_h-y_offset)]) for pt in pos]).astype(np.int32)
        cv2.polylines(target_map, [poly_points], False, 2,10)
    if obj_class == "crosswalk":
        pos = item["data"]
        poly_points = np.array([([pt["x"]*ld.I_W/original_w, (pt["y"] - y_offset)*ld.I_H/(original_h-y_offset)]) for pt in pos]).astype(np.int32)
        if len(poly_points) == 0:
            continue
        cv2.fillPoly(target_map, [poly_points], 3)

# %%
#001
for item in annotation:
    print(item)

# %%
y_offset = original_h - original_w // 2
y_offset

# %%
item = annotation[0]
item

# %%
pos = item["data"]
pos

# %%
poly_points = np.array( [ 
    ( [ pt["x"] * ld.I_W / original_w,
       (pt["y"] - y_offset) * ld.I_H /
       (original_h-y_offset) ] ) for pt in pos
    ]).astype(np.int32)

poly_points

# %%
for pt in pos:
    print(pt)
    print(pt["x"] * ld.I_W / original_w)
    print((pt["y"] - y_offset) * ld.I_H / (original_h-y_offset))

# %%
tmp_arr = cv2.polylines(target_map, [poly_points], False, 1,10)

# %%
for row in tmp_arr:
    print(row)

# %%
np.set_printoptions(threshold=512,linewidth=np.inf)

# %%
print(tmp_arr[0])
