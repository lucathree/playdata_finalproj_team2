# %%
import os, shutil, tarfile, glob

# %%
#트레이닝 데이터이동
n = '1'
day0_night1 = 0
train0_val1 = 0
trval = []
trval = 'train_', 'validation_'
day = []
day = 'daylight_', 'night_'
# such_imagefolder = '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_' + n + '/c_1280_720_daylight_train_' + n 
such_folder = '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_'+ day[day0_night1] +'train_' + n 
image_folder = '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_'+ day[day0_night1] +'train_' + n + '/image'
jason_folder = '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_'+ day[day0_night1] +'train_' + n + '/json'
# such_imagefolder

# %%
#밸리데이션 이동
n = '1'
day0_night1 = 1
day = []
day = 'daylight_', 'night_'
# such_imagefolder = '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_' + n + '/c_1280_720_daylight_train_' + n 
such_folder = '/home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_'+ day[day0_night1] +'validation_' + n 
image_folder = '/home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_'+ day[day0_night1] +'validation_' + n + '/image'
jason_folder = '/home/ubuntu/aiml/data/traffic_lane/Validation/c_1280_720_'+ day[day0_night1] +'validation_' + n + '/json'
# such_imagefolder

# %%
# ## 야간 자료 구성
# n = '4'
# such_folder = '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_' + n 
# image_folder = '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_' + n + '/image'
# jason_folder = '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_night_train_' + n + '/json'

# %%
# ## 임시 자료 이동
# # n = '4'
# such_folder = '/home/ubuntu/aiml/data/traffic_lane/Training'
# image_folder = '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_2/image'
# jason_folder = '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_2/json'

# %%
print(such_folder)
print(image_folder)
print(jason_folder)
# Out:
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/image
# /home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/json

# %%
if not os.path.exists(image_folder):
    os.mkdir(image_folder)
    
if not os.path.exists(jason_folder):
    os.mkdir(jason_folder)

# %%
os.listdir(such_folder)
# Out:
# ['[라벨]c_1280_720_daylight_train_1.zip',
#  'image',
#  'json',
#  '[원천]c_1280_720_daylight_train_1.tar']

# %% [markdown]
# # 이미지 파일 이동
# for root, subdirs, files in os.walk(such_imagefolder):
#     for f in files:
#         if '.jpg' in f:
#             file_to_move = os.path.join(root, f)
#             shutil.move(file_to_move, image_folder)

# %% [markdown]
# # 제이슨 파일 이동
# for root, subdirs, files in os.walk(such_jsonfolder):
#     for f in files:
#         if '.json' in f:
#             file_to_move = os.path.join(root, f)
#             shutil.move(file_to_move, jason_folder)

# %%
# 하위 폴더를 포함한 검색폴더에서 이미지파일과 제이슨 파일의 이동
if os.path.exists(image_folder) and os.path.exists(jason_folder):
    
    for root, subdirs, files in os.walk(such_folder):
        for f in files:
            if '.jpg' in f:
                file_to_move = os.path.join(root, f)
                shutil.move(file_to_move, image_folder)
                            
            elif '.json' in f:
                file_to_move = os.path.join(root, f)
                shutil.move(file_to_move, jason_folder)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /tmp/ipykernel_20027/2324331227.py in <module>
#      10             elif '.json' in f:
#      11                 file_to_move = os.path.join(root, f)
# ---> 12                 shutil.move(file_to_move, jason_folder)
#
# ~/anaconda3/envs/team2/lib/python3.7/shutil.py in move(src, dst, copy_function)
#     562         real_dst = os.path.join(dst, _basename(src))
#     563         if os.path.exists(real_dst):
# --> 564             raise Error("Destination path '%s' already exists" % real_dst)
#     565     try:
#     566         os.rename(src, real_dst)
#
# Error: Destination path '/home/ubuntu/aiml/data/traffic_lane/Training/c_1280_720_daylight_train_1/json/16718158.json' already exists

# %%
# #현재 폴더에서만 검색 후 이동
# for filename in glob.glob('/home/ubuntu/aiml/data/traffic_lane/Training/*.json'):
#     file_to_move = filename
#     print(file_to_move)

#     shutil.move(file_to_move, jason_folder)
# Out:
# /home/ubuntu/aiml/data/traffic_lane/Training/3801826.json
# /home/ubuntu/aiml/data/traffic_lane/Training/16739904.json
# /home/ubuntu/aiml/data/traffic_lane/Training/9909326.json
# /home/ubuntu/aiml/data/traffic_lane/Training/3811905.json
# /home/ubuntu/aiml/data/traffic_lane/Training/16789806.json
# /home/ubuntu/aiml/data/traffic_lane/Training/3800359.json
# /home/ubuntu/aiml/data/traffic_lane/Training/3803218.json
# /home/ubuntu/aiml/data/traffic_lane/Training/3802409.json
# /home/ubuntu/aiml/data/traffic_lane/Training/3805000.json
# /home/ubuntu/aiml/data/traffic_lane/Training/16757333.json
# /home/ubuntu/aiml/data/traffic_lane/Training/16793096.json
# /home/ubuntu/aiml/data/traffic_lane/Training/16797708.json
# /home/ubuntu/aiml/data/traffic_lane/Training/10023959.json
# /home/ubuntu/aiml/data/traffic_lane/Training/9925144.json
# /home/ubuntu/aiml/data/traffic_lane/Training/16747553.json
# /home/ubuntu/aiml/data/traffic_lane/Training/3792919.json
# ...
